# %% [markdown]
# # Lösung: Musterbeispiel 8 – Speicherplatz Stereo-Audio
#
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 7](03_Musterbeispiel_7_Kanalkapazitaet.ipynb) | [→ Musterbeispiel 10](03_Musterbeispiel_10_Audio_Kanal.ipynb) | **Aufgabe:** [03_Musterbeispiel_8](03_Musterbeispiel_8_Stereo_Speicher.ipynb)

# %% [markdown]
# ## Fragestellung
#
# Ein Audiorecorder nimmt ein **Stereo-Audiosignal** mit einer **Abtastrate von 44,1 kHz** und einer **Amplitudenauflösung von 16 bit** auf. Wieviel **Speicherplatz** ist für **1 Stunde** notwendig, wenn keine Datenkompression gemacht wird (z. B. WAV-Datei)?

# %% [markdown]
# ## Antwort (aus dem Skriptum)
#
# - Pro Sekunde: $44\,100$ Samples, 16 Bit pro Sample, **2 Kanäle** (Stereo):
#   $$44\,100 \cdot 16 \cdot 2 = 705\,600\,\mathrm{bit/s}$$
#
# - 1 Stunde = 3600 s:
#   $$705\,600 \cdot 3600\,\mathrm{bit} = 2\,540\,160\,000\,\mathrm{bit} = 317\,520\,000\,\mathrm{Byte} \approx 302{,}8\,\mathrm{MByte}$$

# %% [markdown]
# ## Python-Code

# %%
f_abtast = 44_100   # Hz
bit_pro_sample = 16
kanaele = 2        # Stereo
dauer_sec = 3600   # 1 Stunde

bit_pro_sec = f_abtast * bit_pro_sample * kanaele
bits_gesamt = bit_pro_sec * dauer_sec
bytes_gesamt = bits_gesamt // 8
mbyte = bytes_gesamt / (1024 * 1024)

print("Datenrate:", bit_pro_sec, "bit/s")
print("Bits gesamt:", bits_gesamt)
print("Bytes:", bytes_gesamt)
print("Speicherplatz:", round(mbyte, 1), "MByte")
# Out:
# Datenrate: 1411200 bit/s
# Bits gesamt: 5080320000
# Bytes: 635040000
# Speicherplatz: 605.6 MByte

# %% [markdown]
# ---
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 7](03_Musterbeispiel_7_Kanalkapazitaet.ipynb) | [→ Musterbeispiel 10](03_Musterbeispiel_10_Audio_Kanal.ipynb) | [Aufgabe](03_Musterbeispiel_8_Stereo_Speicher.ipynb)
