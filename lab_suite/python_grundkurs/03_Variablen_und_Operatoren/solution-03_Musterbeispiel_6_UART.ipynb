# %% [markdown]
# # Lösung: Musterbeispiel 6 – UART-Übertragungsdauer
#
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 3](03_Musterbeispiel_3_Informationsgehalt.ipynb) | [→ Musterbeispiel 7](03_Musterbeispiel_7_Kanalkapazitaet.ipynb) | **Aufgabe:** [03_Musterbeispiel_6_UART](03_Musterbeispiel_6_UART.ipynb)

# %% [markdown]
# ## Fragestellung
#
# Wie lange dauert die Übertragung eines Files mit **12860 Bytes**, wenn für die Übertragung ein **UART** mit folgender Einstellung verwendet wird:
# - Baudrate **9600 bit/s**
# - 1 Start-Bit, 1 Stop-Bit
# - Kein Parity-Bit?

# %% [markdown]
# ## Antwort (aus dem Skriptum)
#
# - Pro Byte werden **10 Bits** übertragen (1 Start + 8 Daten + 1 Stop).
#
# - Gesamt: $12860 \cdot 10 = 128600$ Bits.
#
# - Übertragungszeit:
#   $$T = \frac{\text{Bits}}{\text{Baudrate}} = \frac{128600\,\mathrm{bit}}{9600\,\mathrm{bit/s}} \approx 13{,}4\,\mathrm{s}$$

# %% [markdown]
# ## Python-Code

# %%
bytes_file = 12_860
bits_per_byte = 10
baudrate = 9600

bits_total = bytes_file * bits_per_byte
T_sec = bits_total / baudrate

print("Bytes:", bytes_file)
print("Bits gesamt:", bits_total)
print("Baudrate:", baudrate, "bit/s")
print("Übertragungsdauer T =", round(T_sec, 2), "s")
# Out:
# Bytes: 12860
# Bits gesamt: 128600
# Baudrate: 9600 bit/s
# Übertragungsdauer T = 13.4 s

# %% [markdown]
# ---
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 3](03_Musterbeispiel_3_Informationsgehalt.ipynb) | [→ Musterbeispiel 7](03_Musterbeispiel_7_Kanalkapazitaet.ipynb) | [Aufgabe](03_Musterbeispiel_6_UART.ipynb)
