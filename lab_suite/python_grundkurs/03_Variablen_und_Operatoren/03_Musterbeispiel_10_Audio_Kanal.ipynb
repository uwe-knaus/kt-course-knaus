# %% [markdown]
# # Musterbeispiel 10: Audio und Kanalkapazität (Kapitel 01)
#
# **Quelle:** Vorlesung *01.Informationstheorie und Codierung* → **6. Wiederholungsbeispiele** – Skript `1.Musterbeispiele__de.md` (Frage 10).
#
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 8](03_Musterbeispiel_8_Stereo_Speicher.ipynb) | [→ Musterbeispiel 11](03_Musterbeispiel_11_Funkkanal_SNR.ipynb) | [Lösung](solution-03_Musterbeispiel_10_Audio_Kanal.ipynb)

# %% [markdown]
# ## Fragestellung
#
# **a)** Ein Audiosignal mit einer Bandbreite von **300 Hz bis 3300 Hz** soll mit **8 bit/Sample** abgetastet und übertragen werden. Welche **Kanalkapazität** in bit/s ist dafür notwendig?
#
# **b)** Es steht ein Uebertragungskanal mit einer Bandbreite von **10 kHz** und einem Signal/Störleistungsverhältnis **SNR = 20 dB** zur Verfügung. Kann das Audiosignal aus a) über diesen Kanal übertragen werden?

# %% [markdown]
# ## Antwort (aus dem Skriptum)
#
# **a)** Nyquist: minimale Abtastrate $\geq 2 \cdot f_\max = 2 \cdot 3300 = 6600\,\mathrm{Hz}$.
#
# $$C = 6600\,\mathrm{Hz} \cdot 8\,\mathrm{bit} = 52\,800\,\mathrm{bit/s} = 52{,}8\,\mathrm{kbit/s}$$
#
# **b)** SNR 20 dB $\Rightarrow$ lineares Verhältnis $10^{20/10} = 100$. Shannon:
#
# $$C = B \cdot \mathrm{ld}(1+\mathrm{SNR}) = 10\,000 \cdot \mathrm{ld}(101) \approx 66{,}58\,\mathrm{kbit/s}$$
#
# Der Kanal hat ausreichende Kapazität (66,58 > 52,8 kbit/s).

# %% [markdown]
# ## Dein Python-Skript
#
# **Aufgabe:** Implementiere a) erforderliche Kanalkapazität (Abtastrate, Bit/Sample) und b) Kanal-Kapazität (Bandbreite, SNR linear, ld(1+SNR)) und vergleiche.

# %%
# Hier deinen Code eintragen

# %% [markdown]
# ---
#
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 8](03_Musterbeispiel_8_Stereo_Speicher.ipynb) | [→ Musterbeispiel 11](03_Musterbeispiel_11_Funkkanal_SNR.ipynb) | [Lösung](solution-03_Musterbeispiel_10_Audio_Kanal.ipynb)
