# %% [markdown]
# # Lösung: Musterbeispiel 7 – Kanalkapazität bei Quantisierung
#
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 6](03_Musterbeispiel_6_UART.ipynb) | [→ Musterbeispiel 8](03_Musterbeispiel_8_Stereo_Speicher.ipynb) | **Aufgabe:** [03_Musterbeispiel_7](03_Musterbeispiel_7_Kanalkapazitaet.ipynb)

# %% [markdown]
# ## Fragestellung
#
# Wir tasten ein Signal mit einer **Taktfrequenz von 10 kHz** ab. Welche **Kanalkapazität** brauchen wir für die Übertragung, wenn
#
# a) **1024** Quantisierungsstufen,
#
# b) **16 384** Quantisierungsstufen
#
# bei der Abtastung verwendet werden?

# %% [markdown]
# ## Antwort (aus dem Skriptum)
#
# - **a)** $1024 = 2^{10}$ → **10 Bit pro Sample**.
#   $$C = 10\,\mathrm{bit} \cdot 10\,000\,\mathrm{Hz} = 100\,\mathrm{kbit/s}$$
#
# - **b)** $16\,384 = 2^{14}$ → **14 Bit pro Sample**.
#   $$C = 14\,\mathrm{bit} \cdot 10\,000\,\mathrm{Hz} = 140\,\mathrm{kbit/s}$$

# %% [markdown]
# ## Python-Code

# %%
import math

f_abtast = 10_000  # Hz

stufen_a = 1024
stufen_b = 16_384

bit_a = round(math.log2(stufen_a))
bit_b = round(math.log2(stufen_b))
C_a = bit_a * f_abtast
C_b = bit_b * f_abtast

print("a) Stufen", stufen_a, "=>", bit_a, "Bit/Sample => C =", C_a / 1000, "kbit/s")
print("b) Stufen", stufen_b, "=>", bit_b, "Bit/Sample => C =", C_b / 1000, "kbit/s")

# %% [markdown]
# ---
# **Navigation:** [← 03 Hauptkapitel](03_Variablen_und_Operatoren.ipynb) | [← Musterbeispiel 6](03_Musterbeispiel_6_UART.ipynb) | [→ Musterbeispiel 8](03_Musterbeispiel_8_Stereo_Speicher.ipynb) | [Aufgabe](03_Musterbeispiel_7_Kanalkapazitaet.ipynb)
